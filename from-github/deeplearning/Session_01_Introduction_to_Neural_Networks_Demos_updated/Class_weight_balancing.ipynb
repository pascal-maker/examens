# %% [markdown]
# # Classweight balancing

# %%
# %matplotlib inline
import os

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import OneHotEncoder
from sklearn import preprocessing
from sklearn.preprocessing import LabelBinarizer

import matplotlib.image as mpimg

import sklearn.metrics as metrics

import tensorflow
import tensorflow as tf



from sklearn.utils import class_weight

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing import image


###### Tensorflow-GPU ########
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if physical_devices:  # Check if the list is not empty
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
else:
    print("No GPU devices found.")

import re

#K.set_image_dim_ordering('tf')
plt.rcParams['image.cmap'] = 'gray'
pd.set_option('display.max_rows',1000)
pd.set_option('display.max_columns',1000)
# Out:
# No GPU devices found.

# %% [markdown]
# ## Bank
#
# A bank tries to predict whether a client will sign a certain insurance contract. The file 'bank.csv' contains data of thousands of clients.
# The features include:
# Input variables:
#
# 1 - age (numeric)
#
# 2 - job : type of job (categorical:admin.", "unknown", "unemployed", "management", "housemaid", "entrepreneur","student", "blue-collar","self-employed","retired","technician","services")
#
# 3 - marital : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
#
# 4 - education (categorical: "unknown","secondary","primary","tertiary")
#
# 5 - default: has credit in default? (binary: "yes","no")
#
# 6 - balance: average yearly balance, in euros (numeric)
#
# 7 - housing: has housing loan? (binary: "yes","no")
#
# 8 - loan: has personal loan? (binary: "yes","no")
#
# 9 - contact: contact communication type (categorical: "unknown","telephone","cellular")
#
# 10 - day: last contact day of the month (numeric)
#
# 11 - month: last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec")
#
# 12 - duration: last contact duration, in seconds (numeric)
#
# 13 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
# 14 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
#
# 15 - previous: number of contacts performed before this campaign and for this client (numeric)
#
# 16 - poutcome: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")
#
#
# The output variable = y. yes meaning the client signed the contract, no meaning the client didn't sign the contract.
#
#
# Your task is to train a conventional feedforward neural network to predict the target y. Use a test set of 10000 samples.

# %%
# Import customer satisfaction datataset

dataset = pd.read_csv('bank.csv',delimiter=';')
dataset.tail()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no

# %%
# Statistical description of the dataset:

dataset.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000

# %%
# in practise the duration column is not available. That's why it needs to be removed from the dataset

# remove the 'duration' column

dataset.drop('duration',axis=1, inplace=True)

# %%
# For all features with a yes/no answers change to numerical values: yes -> 1 and no -> 0

dataset.replace(["no","yes"], [0, 1], inplace=True)
# Out:
# /var/folders/0r/s3s7wy7x0z33qbtj01kxq24w0000gn/T/ipykernel_78224/2114779205.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset.replace(["no","yes"], [0, 1], inplace=True)

# %%
# Apply one-hot encoding to the remaining categorical features. 

# Example: 
# one-hot encoding of job
dataset = pd.concat([dataset,pd.get_dummies(dataset['job'], prefix='job')],axis=1)
dataset.drop(['job'],axis=1, inplace=True)

# one-hot encoding of marital
dataset = pd.concat([dataset,pd.get_dummies(dataset['marital'], prefix='marital')],axis=1)
dataset.drop(['marital'],axis=1, inplace=True)

# one-hot encoding of education
dataset = pd.concat([dataset,pd.get_dummies(dataset['education'], prefix='education')],axis=1)
dataset.drop(['education'],axis=1, inplace=True)

# one-hot encoding of contact
dataset = pd.concat([dataset,pd.get_dummies(dataset['contact'], prefix='contact')],axis=1)
dataset.drop(['contact'],axis=1, inplace=True)

# one-hot encoding of month
dataset = pd.concat([dataset,pd.get_dummies(dataset['month'], prefix='month')],axis=1)
dataset.drop(['month'],axis=1, inplace=True)

# one-hot encoding of poutcome
dataset = pd.concat([dataset,pd.get_dummies(dataset['poutcome'], prefix='poutcome')],axis=1)
dataset.drop(['poutcome'],axis=1, inplace=True)

# %%
# Split dataset into features and targets

y = dataset.y.values
X = dataset.drop('y',axis=1)

print(X.shape)
print(y.shape)
# Out:
# (45211, 47)
# (45211,)

# %%
# Split into training set and test set

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 10000, random_state =0)

# One-hot encoding of the targets
y_train_orig= y_train  # keep the original labels for testing purposes
#y_train = to_categorical(y_train)

# %%
# Normalization of the features: Try Min-Max, standardscaler or robust scaler

# Standardscaler
#scaler = preprocessing.StandardScaler().fit(X_train)
#X_train = scaler.transform(X_train)
#X_test = scaler.transform(X_test)

# MinMax scaler

scaler = preprocessing.MinMaxScaler().fit(X_train)
X_train = np.asarray(scaler.transform(X_train)).astype('float32')
X_test = np.asarray(scaler.transform(X_test)).astype('float32')

# %%
# Train a Neural network on the training data. Use 20 percent of the training data as validation data.

# Initialize the neural network

## parameters of the NN
model = Sequential()
dropoutrate = 0.2
batchsize = 128
inputdim = X_train.shape[1]  #30 input features
adam = tf.keras.optimizers.Adam() # Adam optimizer

model.add(Dense(40, input_dim=inputdim, kernel_initializer='uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(dropoutrate))
model.add(Dense(40, kernel_initializer='uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(dropoutrate))
model.add(Dense(10, kernel_initializer='uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(dropoutrate))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss=tf.keras.losses.binary_crossentropy,optimizer=adam,metrics=['accuracy'])

# Training

history = model.fit(X_train, y_train, epochs=50,validation_split=0.2, batch_size=batchsize,verbose=1)
# Out:
# Epoch 1/50
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6827 - loss: 0.6079 - val_accuracy: 0.8831 - val_loss: 0.4200
# Epoch 2/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - accuracy: 0.8884 - loss: 0.3420 - val_accuracy: 0.8893 - val_loss: 0.3091
# Epoch 3/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8886 - loss: 0.3172 - val_accuracy: 0.8921 - val_loss: 0.3039
# Epoch 4/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8923 - loss: 0.3087 - val_accuracy: 0.8917 - val_loss: 0.3054
# Epoch 5/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - accuracy: 0.8916 - loss: 0.3111 - val_accuracy: 0.8888 - val_loss: 0.3064
# Epoch 6/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8944 - loss: 0.3032 - val_accuracy: 0.8924 - val_loss: 0.3021
# Epoch 7/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 0.8911 - loss: 0.3046 - val_accuracy: 0.8902 - val_loss: 0.3036
# Epoch 8/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8962 - loss: 0.2947 - val_accuracy: 0.8905 - val_loss: 0.3010
# Epoch 9/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.8942 - loss: 0.2981 - val_accuracy: 0.8911 - val_loss: 0.2999
# Epoch 10/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - accuracy: 0.8946 - loss: 0.2990 - val_accuracy: 0.8921 - val_loss: 0.3014
# Epoch 11/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.8939 - loss: 0.2993 - val_accuracy: 0.8898 - val_loss: 0.3008
# Epoch 12/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - accuracy: 0.8940 - loss: 0.2912 - val_accuracy: 0.8918 - val_loss: 0.3008
# Epoch 13/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.8905 - loss: 0.2996 - val_accuracy: 0.8915 - val_loss: 0.2986
# Epoch 14/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.8926 - loss: 0.2943 - val_accuracy: 0.8915 - val_loss: 0.2986
# Epoch 15/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.8934 - loss: 0.2948 - val_accuracy: 0.8911 - val_loss: 0.2986
# Epoch 16/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - accuracy: 0.8941 - loss: 0.2919 - val_accuracy: 0.8915 - val_loss: 0.2976
# Epoch 17/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.8958 - loss: 0.2864 - val_accuracy: 0.8917 - val_loss: 0.2978
# Epoch 18/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 0.8948 - loss: 0.2912 - val_accuracy: 0.8911 - val_loss: 0.3004
# Epoch 19/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 0.8950 - loss: 0.2892 - val_accuracy: 0.8929 - val_loss: 0.2960
# Epoch 20/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.8937 - loss: 0.2908 - val_accuracy: 0.8921 - val_loss: 0.2960
# Epoch 21/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.8932 - loss: 0.2928 - val_accuracy: 0.8919 - val_loss: 0.2987
# Epoch 22/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 0.8939 - loss: 0.2909 - val_accuracy: 0.8925 - val_loss: 0.2978
# Epoch 23/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.8932 - loss: 0.2920 - val_accuracy: 0.8929 - val_loss: 0.2966
# Epoch 24/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8961 - loss: 0.2837 - val_accuracy: 0.8932 - val_loss: 0.2972
# Epoch 25/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 0.8948 - loss: 0.2846 - val_accuracy: 0.8932 - val_loss: 0.2971
# Epoch 26/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.8961 - loss: 0.2814 - val_accuracy: 0.8904 - val_loss: 0.2974
# Epoch 27/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - accuracy: 0.8956 - loss: 0.2905 - val_accuracy: 0.8917 - val_loss: 0.2969
# Epoch 28/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - accuracy: 0.8945 - loss: 0.2870 - val_accuracy: 0.8928 - val_loss: 0.2963
# Epoch 29/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - accuracy: 0.8941 - loss: 0.2867 - val_accuracy: 0.8908 - val_loss: 0.2961
# Epoch 30/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - accuracy: 0.8973 - loss: 0.2831 - val_accuracy: 0.8919 - val_loss: 0.2958
# Epoch 31/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 0.8975 - loss: 0.2832 - val_accuracy: 0.8941 - val_loss: 0.2941
# Epoch 32/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.8998 - loss: 0.2809 - val_accuracy: 0.8908 - val_loss: 0.2956
# Epoch 33/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.9000 - loss: 0.2770 - val_accuracy: 0.8911 - val_loss: 0.2954
# Epoch 34/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 0.8950 - loss: 0.2814 - val_accuracy: 0.8927 - val_loss: 0.2958
# Epoch 35/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.8958 - loss: 0.2833 - val_accuracy: 0.8937 - val_loss: 0.2959
# Epoch 36/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.8951 - loss: 0.2842 - val_accuracy: 0.8905 - val_loss: 0.2957
# Epoch 37/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 0.8997 - loss: 0.2757 - val_accuracy: 0.8905 - val_loss: 0.2956
# Epoch 38/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.8949 - loss: 0.2823 - val_accuracy: 0.8915 - val_loss: 0.2969
# Epoch 39/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - accuracy: 0.8952 - loss: 0.2856 - val_accuracy: 0.8922 - val_loss: 0.2958
# Epoch 40/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - accuracy: 0.8972 - loss: 0.2810 - val_accuracy: 0.8942 - val_loss: 0.2949
# Epoch 41/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - accuracy: 0.8983 - loss: 0.2792 - val_accuracy: 0.8927 - val_loss: 0.2958
# Epoch 42/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 0.8991 - loss: 0.2777 - val_accuracy: 0.8919 - val_loss: 0.2950
# Epoch 43/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 0.8963 - loss: 0.2850 - val_accuracy: 0.8912 - val_loss: 0.2962
# Epoch 44/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.8980 - loss: 0.2811 - val_accuracy: 0.8928 - val_loss: 0.2958
# Epoch 45/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 0.8954 - loss: 0.2787 - val_accuracy: 0.8924 - val_loss: 0.2945
# Epoch 46/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - accuracy: 0.8954 - loss: 0.2817 - val_accuracy: 0.8919 - val_loss: 0.2964
# Epoch 47/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.8949 - loss: 0.2823 - val_accuracy: 0.8914 - val_loss: 0.2973
# Epoch 48/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.8960 - loss: 0.2806 - val_accuracy: 0.8904 - val_loss: 0.2963
# Epoch 49/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.8989 - loss: 0.2769 - val_accuracy: 0.8907 - val_loss: 0.2991
# Epoch 50/50
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.8955 - loss: 0.2833 - val_accuracy: 0.8935 - val_loss: 0.2960

# %%
# Plot of the training history

# Accuray 
plt.plot(history.history['accuracy'],'r')
plt.plot(history.history['val_accuracy'],'b')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Loss 
plt.plot(history.history['loss'],'r')
plt.plot(history.history['val_loss'],'b')

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Testing with the test set

y_pred = (model.predict(X_test) > 0.5).astype('int32')
print('\n')
print(classification_report(y_test, y_pred))

cf = confusion_matrix(y_test, y_pred)

print(cf)
print(accuracy_score(y_test, y_pred) * 100) 

# ROC
preds = y_pred = model.predict(X_test) 
# calculate the fpr and tpr for all thresholds of the classification

fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

# plot
#import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
#
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      8824
#            1       0.59      0.22      0.32      1176
#
#     accuracy                           0.89     10000
#    macro avg       0.75      0.60      0.63     10000
# weighted avg       0.87      0.89      0.87     10000
#
# [[8648  176]
#  [ 920  256]]
# 89.03999999999999
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 262us/step

# %% [markdown]
# ## Classweight balancing
#
# As the data is unbalanced, the neural netwerk tends to have a preference for the majority class.
# One of the approaches is to use classweight balancing. This means that during the training phase, a misclassification of a sample from the minority class results in a higher loss.

# %%
# Histogram of the classcount
label_count = np.bincount(y)

print('count klasse 0: ',label_count[0])
print('count klasse 1: ',label_count[1])

print('ratio: ',label_count[0]/label_count[1])


sns.catplot(x='y',kind='count', data=dataset)
# Out:
# count klasse 0:  39922
# count klasse 1:  5289
# ratio:  7.548118737001324

# %%
# Train a Neural network on the training data. Use 20 percent of the training data as validation data.

# Initialize the neural network

## parameters of the NN
model = Sequential()
dropoutrate = 0.2
batchsize = 64
epochs = 10
inputdim = X_train.shape[1]  #30 input features
adam = tf.keras.optimizers.Adam() # Adam optimizer


model.add(Dense(40, input_dim=inputdim, kernel_initializer='uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(dropoutrate))
model.add(Dense(40, kernel_initializer='uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(dropoutrate))
model.add(Dense(10, kernel_initializer='uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(dropoutrate))
model.add(Dense(1, activation='sigmoid'))


model.compile(loss='binary_crossentropy',optimizer=adam,metrics=['accuracy'])

class_weights = class_weight.compute_class_weight(class_weight='balanced',classes=np.unique(y_train_orig),y=y_train_orig)
print(class_weights)
class_weights= dict(enumerate(class_weights))


history = model.fit(X_train, y_train, validation_split=0.2, epochs=epochs, verbose=1,class_weight=class_weights)
# Out:
# [0.56612965 4.28045222]
# Epoch 1/10
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 936us/step - accuracy: 0.6493 - loss: 0.6502 - val_accuracy: 0.7461 - val_loss: 0.5778
# Epoch 2/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 1s 814us/step - accuracy: 0.7216 - loss: 0.5920 - val_accuracy: 0.7836 - val_loss: 0.5369
# Epoch 3/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 1s 791us/step - accuracy: 0.7682 - loss: 0.5695 - val_accuracy: 0.8055 - val_loss: 0.5337
# Epoch 4/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - accuracy: 0.7721 - loss: 0.5682 - val_accuracy: 0.7759 - val_loss: 0.5571
# Epoch 5/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 1s 682us/step - accuracy: 0.7687 - loss: 0.5711 - val_accuracy: 0.8055 - val_loss: 0.5234
# Epoch 6/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 1s 789us/step - accuracy: 0.7840 - loss: 0.5559 - val_accuracy: 0.8090 - val_loss: 0.5477
# Epoch 7/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 1s 708us/step - accuracy: 0.7918 - loss: 0.5562 - val_accuracy: 0.8069 - val_loss: 0.5265
# Epoch 8/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 1s 699us/step - accuracy: 0.7881 - loss: 0.5446 - val_accuracy: 0.8170 - val_loss: 0.5566
# Epoch 9/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 1s 803us/step - accuracy: 0.7958 - loss: 0.5462 - val_accuracy: 0.8099 - val_loss: 0.5659
# Epoch 10/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 1s 698us/step - accuracy: 0.7988 - loss: 0.5673 - val_accuracy: 0.8374 - val_loss: 0.5096

# %%
# Plot history

# Accuray 
plt.plot(history.history['accuracy'],'r')
plt.plot(history.history['val_accuracy'],'b')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Loss 
plt.plot(history.history['loss'],'r')
plt.plot(history.history['val_loss'],'b')

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
class_weights[1] = 20
print(class_weights)
# Out:
# {0: 0.5661296546401697, 1: 20}

# %%
# Testing

y_pred = (model.predict(X_test) > 0.5).astype('int32')
print('\n')
print(classification_report(y_test, y_pred))

cf = confusion_matrix(y_test, y_pred)

print(cf)
print(accuracy_score(y_test, y_pred) * 100) 

# ROC
preds = y_pred = model.predict(X_test) 
# calculate the fpr and tpr for all thresholds of the classification

fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

# plot
#import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
#
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91      8824
#            1       0.39      0.56      0.46      1176
#
#     accuracy                           0.84     10000
#    macro avg       0.66      0.72      0.68     10000
# weighted avg       0.87      0.84      0.86     10000
#
# [[7777 1047]
#  [ 512  664]]
# 84.41
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 286us/step

# %% [markdown]
# ## Oversampling
#
# Another way of dealing with unbalanced data is to oversample the data. This means that the data will be balanced by creating additional samples from the minority class until equilibrium.

# %%
# Oversampling with SMOTE
from imblearn.over_sampling import BorderlineSMOTE
X_resampled, y_resampled = BorderlineSMOTE().fit_resample(X_train, y_train_orig)

y_resampled_orig = y_resampled
#y_resampled = to_categorical(y_resampled)

# %%
# !conda activate base      # or your ML env
# !conda install ipykernel
# !python -m ipykernel install --user --name ml-env --display-name "Python (ML)"
# Out:
#   Cell In[28], line 1
#     conda activate base      # or your ML env
#           ^
# SyntaxError: invalid syntax

# %%
conda activate base   # or ml-env
conda install -c conda-forge scikit-learn imbalanced-learn
# Out:
#   Cell In[1], line 1
#     conda activate base   # or ml-env
#           ^
# SyntaxError: invalid syntax

# %%
# !pip install --upgrade imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /opt/anaconda3/lib/python3.12/site-packages (0.10.1)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.14.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy<3,>=1.25.2 in /opt/anaconda3/lib/python3.12/site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy<2,>=1.11.4 in /opt/anaconda3/lib/python3.12/site-packages (from imbalanced-learn) (1.15.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /opt/anaconda3/lib/python3.12/site-packages (from imbalanced-learn) (1.7.2)
# Requirement already satisfied: joblib<2,>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from imbalanced-learn) (3.5.0)
# Downloading imbalanced_learn-0.14.0-py3-none-any.whl (239 kB)
# Installing collected packages: imbalanced-learn
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.10.1
#     Uninstalling imbalanced-learn-0.10.1:
#       Successfully uninstalled imbalanced-learn-0.10.1
# Successfully installed imbalanced-learn-0.14.0

# %%
! pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.12/site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (3.5.0)

# %%
# !pip install imblearn
# Out:
# Collecting imblearn
#   Using cached imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Requirement already satisfied: imbalanced-learn in /opt/anaconda3/lib/python3.12/site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /opt/anaconda3/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in /opt/anaconda3/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.7.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (3.5.0)
# Using cached imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Installing collected packages: imblearn
# Successfully installed imblearn-0.0

# %%
# Train a Neural network on the training data. Use 20 percent of the training data as validation data.

# Initialize the neural network

## parameters of the NN
model = Sequential()
dropoutrate = 0.2
batchsize = 64
inputdim = X_train.shape[1]  #30 input features
adam = tf.keras.optimizers.Adam() # Adam optimizer
#sgd = tf.keras.optimizers.sgd(lr=0.001)


model.add(Dense(40, input_dim=inputdim, kernel_initializer='uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(dropoutrate))
model.add(Dense(40, kernel_initializer='uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(dropoutrate))
model.add(Dense(10, kernel_initializer='uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(dropoutrate))
model.add(Dense(1, activation='sigmoid'))


model.compile(loss='binary_crossentropy',optimizer=adam,metrics=['accuracy'])

# Training

history = model.fit(X_resampled, y_resampled, epochs=50,validation_split=0.2, batch_size=batchsize,verbose=1)
# Out:
# Epoch 1/50
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 2s 922us/step - accuracy: 0.7115 - loss: 0.5670 - val_accuracy: 0.6214 - val_loss: 0.7380
# Epoch 2/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 744us/step - accuracy: 0.7641 - loss: 0.5117 - val_accuracy: 0.6225 - val_loss: 0.7160
# Epoch 3/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 755us/step - accuracy: 0.7687 - loss: 0.5007 - val_accuracy: 0.6728 - val_loss: 0.6045
# Epoch 4/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 728us/step - accuracy: 0.7766 - loss: 0.4889 - val_accuracy: 0.6360 - val_loss: 0.6678
# Epoch 5/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 748us/step - accuracy: 0.7777 - loss: 0.4882 - val_accuracy: 0.6494 - val_loss: 0.6067
# Epoch 6/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 745us/step - accuracy: 0.7797 - loss: 0.4818 - val_accuracy: 0.6379 - val_loss: 0.6307
# Epoch 7/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 723us/step - accuracy: 0.7813 - loss: 0.4774 - val_accuracy: 0.6590 - val_loss: 0.6114
# Epoch 8/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 774us/step - accuracy: 0.7836 - loss: 0.4735 - val_accuracy: 0.6529 - val_loss: 0.6137
# Epoch 9/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 790us/step - accuracy: 0.7861 - loss: 0.4705 - val_accuracy: 0.6681 - val_loss: 0.5618
# Epoch 10/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.7879 - loss: 0.4670 - val_accuracy: 0.7144 - val_loss: 0.5113
# Epoch 11/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 762us/step - accuracy: 0.7867 - loss: 0.4670 - val_accuracy: 0.6954 - val_loss: 0.5528
# Epoch 12/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - accuracy: 0.7922 - loss: 0.4624 - val_accuracy: 0.7141 - val_loss: 0.5306
# Epoch 13/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 712us/step - accuracy: 0.7922 - loss: 0.4604 - val_accuracy: 0.7078 - val_loss: 0.5419
# Epoch 14/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 720us/step - accuracy: 0.7915 - loss: 0.4599 - val_accuracy: 0.6887 - val_loss: 0.5429
# Epoch 15/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 709us/step - accuracy: 0.7924 - loss: 0.4569 - val_accuracy: 0.7010 - val_loss: 0.5430
# Epoch 16/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 710us/step - accuracy: 0.7937 - loss: 0.4559 - val_accuracy: 0.7368 - val_loss: 0.5043
# Epoch 17/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - accuracy: 0.7953 - loss: 0.4574 - val_accuracy: 0.7301 - val_loss: 0.5152
# Epoch 18/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - accuracy: 0.7942 - loss: 0.4573 - val_accuracy: 0.7269 - val_loss: 0.5276
# Epoch 19/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 762us/step - accuracy: 0.7963 - loss: 0.4544 - val_accuracy: 0.7303 - val_loss: 0.4971
# Epoch 20/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 715us/step - accuracy: 0.8009 - loss: 0.4495 - val_accuracy: 0.7223 - val_loss: 0.5323
# Epoch 21/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 733us/step - accuracy: 0.7946 - loss: 0.4570 - val_accuracy: 0.7253 - val_loss: 0.5373
# Epoch 22/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 732us/step - accuracy: 0.7991 - loss: 0.4487 - val_accuracy: 0.7425 - val_loss: 0.5100
# Epoch 23/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 710us/step - accuracy: 0.7973 - loss: 0.4521 - val_accuracy: 0.7256 - val_loss: 0.5229
# Epoch 24/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - accuracy: 0.7963 - loss: 0.4492 - val_accuracy: 0.7132 - val_loss: 0.5342
# Epoch 25/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 734us/step - accuracy: 0.7996 - loss: 0.4507 - val_accuracy: 0.7231 - val_loss: 0.5273
# Epoch 26/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 765us/step - accuracy: 0.7985 - loss: 0.4492 - val_accuracy: 0.7224 - val_loss: 0.5336
# Epoch 27/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - accuracy: 0.8004 - loss: 0.4472 - val_accuracy: 0.7369 - val_loss: 0.5117
# Epoch 28/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step - accuracy: 0.8023 - loss: 0.4446 - val_accuracy: 0.7261 - val_loss: 0.5343
# Epoch 29/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - accuracy: 0.8003 - loss: 0.4458 - val_accuracy: 0.7605 - val_loss: 0.4891
# Epoch 30/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 699us/step - accuracy: 0.8019 - loss: 0.4483 - val_accuracy: 0.7334 - val_loss: 0.5121
# Epoch 31/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - accuracy: 0.8048 - loss: 0.4400 - val_accuracy: 0.7357 - val_loss: 0.5176
# Epoch 32/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - accuracy: 0.8019 - loss: 0.4442 - val_accuracy: 0.7469 - val_loss: 0.4922
# Epoch 33/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 754us/step - accuracy: 0.8032 - loss: 0.4434 - val_accuracy: 0.7740 - val_loss: 0.4669
# Epoch 34/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 704us/step - accuracy: 0.8031 - loss: 0.4448 - val_accuracy: 0.7642 - val_loss: 0.4883
# Epoch 35/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 725us/step - accuracy: 0.8020 - loss: 0.4466 - val_accuracy: 0.7466 - val_loss: 0.4911
# Epoch 36/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 704us/step - accuracy: 0.8041 - loss: 0.4428 - val_accuracy: 0.7638 - val_loss: 0.4750
# Epoch 37/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step - accuracy: 0.8021 - loss: 0.4446 - val_accuracy: 0.7679 - val_loss: 0.4782
# Epoch 38/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 708us/step - accuracy: 0.8047 - loss: 0.4428 - val_accuracy: 0.7543 - val_loss: 0.4993
# Epoch 39/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step - accuracy: 0.8024 - loss: 0.4397 - val_accuracy: 0.7749 - val_loss: 0.4658
# Epoch 40/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 751us/step - accuracy: 0.8001 - loss: 0.4442 - val_accuracy: 0.7640 - val_loss: 0.4928
# Epoch 41/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 738us/step - accuracy: 0.8040 - loss: 0.4427 - val_accuracy: 0.7596 - val_loss: 0.4952
# Epoch 42/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 723us/step - accuracy: 0.8060 - loss: 0.4418 - val_accuracy: 0.7700 - val_loss: 0.4717
# Epoch 43/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 718us/step - accuracy: 0.8040 - loss: 0.4396 - val_accuracy: 0.7432 - val_loss: 0.5143
# Epoch 44/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 721us/step - accuracy: 0.8050 - loss: 0.4372 - val_accuracy: 0.7993 - val_loss: 0.4301
# Epoch 45/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 707us/step - accuracy: 0.8013 - loss: 0.4441 - val_accuracy: 0.7825 - val_loss: 0.4801
# Epoch 46/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 707us/step - accuracy: 0.8065 - loss: 0.4398 - val_accuracy: 0.7920 - val_loss: 0.4548
# Epoch 47/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 742us/step - accuracy: 0.8056 - loss: 0.4379 - val_accuracy: 0.7824 - val_loss: 0.4579
# Epoch 48/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step - accuracy: 0.8046 - loss: 0.4394 - val_accuracy: 0.7515 - val_loss: 0.4857
# Epoch 49/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 734us/step - accuracy: 0.8049 - loss: 0.4408 - val_accuracy: 0.7659 - val_loss: 0.4771
# Epoch 50/50
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 1s 747us/step - accuracy: 0.8035 - loss: 0.4421 - val_accuracy: 0.7826 - val_loss: 0.4631

# %%
# Plot history

# Accuray 
plt.plot(history.history['accuracy'],'r')
plt.plot(history.history['val_accuracy'],'b')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Loss 
plt.plot(history.history['loss'],'r')
plt.plot(history.history['val_loss'],'b')

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Testing

y_pred = (model.predict(X_test) > 0.5).astype('int32')
print('\n')
print(classification_report(y_test, y_pred))

cf = confusion_matrix(y_test, y_pred)

print(cf)
print(accuracy_score(y_test, y_pred) * 100) 

# ROC
preds = y_pred = model.predict(X_test) 
# calculate the fpr and tpr for all thresholds of the classification

fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

# plot
#import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
#
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.91      8824
#            1       0.37      0.53      0.44      1176
#
#     accuracy                           0.84     10000
#    macro avg       0.65      0.70      0.67     10000
# weighted avg       0.87      0.84      0.85     10000
#
# [[7759 1065]
#  [ 552  624]]
# 83.83
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 281us/step
